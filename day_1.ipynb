# %% [markdown]
# DAY 1

# %%
import os
import pandas as pd

# %%
os.listdir('Mats')
# Out:
# ['2023-nwbc-data.csv',
#  '2023-nwbc-raw-data.csv',
#  '2023-nwbc-reds-updated.csv',
#  '2023-nwbc-reds.csv',
#  '2023-nwbc-reds.xlsx',
#  'nw-version-reds.xlsx']

# %%
df = pd.read_csv("/Baseball/Mats/2023-nwbc-reds.csv")

# %%
df.head()
# Out:
#   pitch_type   game_date  release_speed  release_pos_x  release_pos_z
# 0         FF  05-10-2022           93.8           2.39           5.44  \
# 1         FF  05-10-2022           93.3           2.30           5.51
# 2         SL  05-10-2022           84.3           2.45           5.21
# 3         FF  05-10-2022           93.8           2.32           5.48
# 4         FF  05-10-2022           94.1           2.34           5.54
#
#       pitcher_name  batter  pitcher     events      description  ...
# 0  Hughes, Brandon  605244   676714  field_out    hit_into_play  ...  \
# 1  Hughes, Brandon  605244   676714        NaN             ball  ...
# 2  Hughes, Brandon  605244   676714        NaN             ball  ...
# 3  Hughes, Brandon  605244   676714        NaN    called_strike  ...
# 4  Hughes, Brandon  605244   676714        NaN  swinging_strike  ...
#
#    of_fielding_alignment  spin_axis  delta_home_win_exp  delta_run_exp
# ...

# %%
df.columns
# Out:
# Index(['pitch_type', 'game_date', 'release_speed', 'release_pos_x',
#        'release_pos_z', 'pitcher_name', 'batter', 'pitcher', 'events',
#        'description', 'spin_dir', 'spin_rate_deprecated',
#        'break_angle_deprecated', 'break_length_deprecated', 'zone', 'des',
#        'game_type', 'stand', 'p_throws', 'home_team', 'away_team', 'type',
#        'hit_location', 'bb_type', 'balls', 'strikes', 'game_year', 'pfx_x',
#        'pfx_z', 'plate_x', 'plate_z', 'on_3b', 'on_2b', 'on_1b',
#        'outs_when_up', 'inning', 'inning_topbot', 'hc_x', 'hc_y',
#        'tfs_deprecated', 'tfs_zulu_deprecated', 'fielder_2', 'umpire', 'sv_id',
#        'vx0', 'vy0', 'vz0', 'ax', 'ay', 'az', 'sz_top', 'sz_bot',
#        'hit_distance_sc', 'launch_speed', 'launch_angle', 'effective_speed',
#        'release_spin_rate', 'release_extension', 'game_pk', 'pitcher.1',
#        'fielder_2.1', 'fielder_3', 'fielder_4', 'fielder_5', 'fielder_6',
# ...

# %%
df['home_score']

#Adding a new column

df['Total_Score'] = df['home_score'] + df['away_score']

# %%
df['description'].unique()
# Out:
# array(['hit_into_play', 'ball', 'called_strike', 'swinging_strike',
#        'foul', 'blocked_ball', 'swinging_strike_blocked', 'hit_by_pitch',
#        'foul_tip', 'foul_bunt', 'missed_bunt', 'bunt_foul_tip',
#        'pitchout'], dtype=object)

# %%
strike_events = ['called_strike', 'swinging_strike', 'foul', 'swinging_strike_blocked', 'foul_tip', 'foul_bunt', 'missed_bunt', 'bunt_foul_tip']

# %%
df.loc[df['description'].isin(strike_events)]
# Out:
#       pitch_type   game_date  release_speed  release_pos_x  release_pos_z
# 3             FF  05-10-2022           93.8           2.32           5.48  \
# 4             FF  05-10-2022           94.1           2.34           5.54
# 6             FF  05-10-2022           94.5           2.25           5.47
# 9             SI  05-10-2022           93.4           2.36           5.41
# 12            FF  05-10-2022           92.7           2.45           5.40
# ...          ...         ...            ...            ...            ...
# 49033        NaN  31-03-2022            NaN            NaN            NaN
# 49034        NaN  31-03-2022            NaN            NaN            NaN
# 49035        NaN  31-03-2022            NaN            NaN            NaN
# 49036        NaN  31-03-2022            NaN            NaN            NaN
# 49037        NaN  31-03-2022            NaN            NaN            NaN
#
#           pitcher_name  batter  pitcher     events      description  ...
# ...

# %%
df['is_strike'] = 0
df.loc[df['description'].isin(strike_events), 'is_strike'] = 1

# %%
df.head(10)
# Out:
#   pitch_type   game_date  release_speed  release_pos_x  release_pos_z
# 0         FF  05-10-2022           93.8           2.39           5.44  \
# 1         FF  05-10-2022           93.3           2.30           5.51
# 2         SL  05-10-2022           84.3           2.45           5.21
# 3         FF  05-10-2022           93.8           2.32           5.48
# 4         FF  05-10-2022           94.1           2.34           5.54
# 5         FF  05-10-2022           93.8           2.33           5.50
# 6         FF  05-10-2022           94.5           2.25           5.47
# 7         FF  05-10-2022           92.8           2.48           5.40
# 8         FF  05-10-2022           94.7           2.32           5.55
# 9         SI  05-10-2022           93.4           2.36           5.41
#
#       pitcher_name  batter  pitcher     events      description  ...
# 0  Hughes, Brandon  605244   676714  field_out    hit_into_play  ...  \
# ...

# %% [markdown]
# HOMEWORK

# %% [markdown]
# Question 1
#
# Use the strikes column to find where there are 2 strikes and make a new column indicating whether the pitch was thrown in a 2-strike situation. Name this is_2_strikes

# %%
df['is_2_strikes'] = 0

df.loc[df['strikes'] == 2, 'is_2_strikes' ] = 1

# %%
df.head(10)
# Out:
#   pitch_type   game_date  release_speed  release_pos_x  release_pos_z
# 0         FF  05-10-2022           93.8           2.39           5.44  \
# 1         FF  05-10-2022           93.3           2.30           5.51
# 2         SL  05-10-2022           84.3           2.45           5.21
# 3         FF  05-10-2022           93.8           2.32           5.48
# 4         FF  05-10-2022           94.1           2.34           5.54
# 5         FF  05-10-2022           93.8           2.33           5.50
# 6         FF  05-10-2022           94.5           2.25           5.47
# 7         FF  05-10-2022           92.8           2.48           5.40
# 8         FF  05-10-2022           94.7           2.32           5.55
# 9         SI  05-10-2022           93.4           2.36           5.41
#
#       pitcher_name  batter  pitcher     events      description  ...
# 0  Hughes, Brandon  605244   676714  field_out    hit_into_play  ...  \
# ...

# %% [markdown]
# Question 2
#
# Use the release_speed column to find when a pitch is thrown greater than 94 MPH (the column is in MPH already). Name this is_high_velo

# %%
df['is_high_velo'] = 0
df.loc[df['release_speed'] > 94, 'is_high_velo' ] = 1

# %%
df.head(10)
# Out:
#   pitch_type   game_date  release_speed  release_pos_x  release_pos_z
# 0         FF  05-10-2022           93.8           2.39           5.44  \
# 1         FF  05-10-2022           93.3           2.30           5.51
# 2         SL  05-10-2022           84.3           2.45           5.21
# 3         FF  05-10-2022           93.8           2.32           5.48
# 4         FF  05-10-2022           94.1           2.34           5.54
# 5         FF  05-10-2022           93.8           2.33           5.50
# 6         FF  05-10-2022           94.5           2.25           5.47
# 7         FF  05-10-2022           92.8           2.48           5.40
# 8         FF  05-10-2022           94.7           2.32           5.55
# 9         SI  05-10-2022           93.4           2.36           5.41
#
#       pitcher_name  batter  pitcher     events      description  ...
# 0  Hughes, Brandon  605244   676714  field_out    hit_into_play  ...  \
# ...

# %% [markdown]
# Question 3
#
# Use the description column AND the attack_zone column to indicate when a pitch is thrown for a called or swinging strike (not a foul) in the "heart" attack zone (hint: this requires two conditional statements! maybe google or ask for help in the discord!)

# %%
onli_strike = ['called_strike', 'swinging_strike']

# %%
df['is_heart_zone'] = 0
df.loc[(df['description'].isin(onli_strike)) & (df['attack_zone'] == 'heart'), 'is_heart_zone'] = 1

# %%
df.head(10)
# Out:
#   pitch_type   game_date  release_speed  release_pos_x  release_pos_z
# 0         FF  05-10-2022           93.8           2.39           5.44  \
# 1         FF  05-10-2022           93.3           2.30           5.51
# 2         SL  05-10-2022           84.3           2.45           5.21
# 3         FF  05-10-2022           93.8           2.32           5.48
# 4         FF  05-10-2022           94.1           2.34           5.54
# 5         FF  05-10-2022           93.8           2.33           5.50
# 6         FF  05-10-2022           94.5           2.25           5.47
# 7         FF  05-10-2022           92.8           2.48           5.40
# 8         FF  05-10-2022           94.7           2.32           5.55
# 9         SI  05-10-2022           93.4           2.36           5.41
#
#       pitcher_name  batter  pitcher     events      description  ...
# 0  Hughes, Brandon  605244   676714  field_out    hit_into_play  ...  \
# ...

# %%
df.to_csv("/Baseball/Mats/2023-nwbc-reds-updated.csv")
